# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## 1. Load the dataset into python environment

data=pd.read_csv(r"C:\Users\Workstation X\Desktop\ICT\Assignment 4\titanic_dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## 2. Make ‘PassengerId’ as the index column

data.set_index('PassengerId',inplace=True)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
## 3. Check the basic details of the dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.shape
# Out:
# (891, 11)

# %%
data.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
## 4. Fill in all the missing values present in all the columns in the dataset

data.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
## To display columns with missing values
columns_with_missing_values = data.columns[data.isna().any()].tolist()

print("Columns with missing values:")
for column in columns_with_missing_values:
    print(column)
# Out:
# Columns with missing values:
# Age
# Cabin
# Embarked

# %%
## Filling the missing values in these 3 columns.

## Fill missing "Age" values with the mean
data['Age'].fillna(data['Age'].mean(), inplace=True)

## Filling the missing value as "Unknown" in Cabin & Embarked column
data['Cabin'].fillna('Unknown', inplace=True)
data['Embarked'].fillna('Unknown', inplace=True)

data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
## Checking if there are still any missing values

columns_with_missing_values_2 = data.columns[data.isna().any()].tolist()
print("Columns with missing values:")
for column in columns_with_missing_values_2:
    print(column)
else:
    print("No missing values")
# Out:
# Columns with missing values:
# No missing values

# %%
## Create a box plot for the "Age" column

plt.figure(figsize=(8, 6))
plt.boxplot(data['Age']) 
plt.title('Box Plot for Age')
plt.xlabel('Age')

plt.figure(figsize=(8, 6))
plt.boxplot(data['Fare']) 
plt.title('Box Plot for Fare')
plt.xlabel('Fare')

plt.figure(figsize=(8, 6))
plt.boxplot(data['Pclass']) 
plt.title('Box Plot for Passenger Class')
plt.xlabel('Pclass')

plt.show()

# %%
## IQR Method

Q1_age = data['Age'].quantile(0.25)
Q3_age = data['Age'].quantile(0.75)
IQR_age = Q3_age - Q1_age
print("IQR of Age column:", IQR_age)

Q1_fare = data['Fare'].quantile(0.25)
Q3_fare = data['Fare'].quantile(0.75)
IQR_fare = Q3_fare - Q1_fare
print("IQR of Fare column:", IQR_fare)

Q1_Pclass = data['Pclass'].quantile(0.25)
Q3_Pclass = data['Pclass'].quantile(0.75)
IQR_Pclass = Q3_Pclass - Q1_Pclass
print("IQR of Pclass column:", IQR_Pclass)
# Out:
# IQR of Age column: 13.0
# IQR of Fare column: 23.0896
# IQR of Pclass column: 1.0

# %%
data[(data['Age']< Q1_age-1.5* IQR_age) | (data['Age']> Q3_age+1.5* IQR_age)]
data[(data['Fare']< Q1_fare-1.5* IQR_fare) | (data['Fare']> Q3_fare+1.5* IQR_fare)]
data[(data['Pclass']< Q1_Pclass-1.5* IQR_Pclass) | (data['Pclass']> Q3_Pclass+1.5* IQR_Pclass)]
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Separate the target ("Survived") from the features
target = data['Survived']
features = data.drop(columns=['Survived'])

# Identify numerical columns (exclude categorical columns)
numerical_columns = features.select_dtypes(include=['number']).columns

scaler = MinMaxScaler()

# Apply MinMax scaling to the numerical features
features[numerical_columns] = scaler.fit_transform(features[numerical_columns])

# Combine the scaled features and the target back into a DataFrame
data_scaled = pd.concat([features, target], axis=1)

data_scaled
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1               1.0                            Braund, Mr. Owen Harris
# 2               0.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3               1.0                             Heikkinen, Miss. Laina
# 4               0.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5               1.0                           Allen, Mr. William Henry
# ...             ...                                                ...
# 887             0.5                              Montvila, Rev. Juozas
# 888             0.0                       Graham, Miss. Margaret Edith
# 889             1.0           Johnston, Miss. Catherine Helen "Carrie"
# 890             0.0                              Behr, Mr. Karl Howell
# 891             1.0                                Dooley, Mr. Patrick
#
#                 Sex       Age  SibSp     Parch            Ticket      Fare  \
# PassengerId
# ...
